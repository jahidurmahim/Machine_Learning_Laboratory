# %% [markdown]
# <a href="https://colab.research.google.com/github/jahidurmahim/GHG-CO2-Agrifood-prediction/blob/main/Data_Processing_for_GHGAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Import Libraries**
# This cell imports the necessary Python libraries for data manipulation, visualization, and numerical operations.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### **Load Dataset**

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/FAO_GreenHouseGasEmission.csv')

# %% [markdown]
# ### **Display First Rows**
# This cell displays the first 5 rows of the DataFrame `df` to get a quick overview of the data.

# %%
df.head()
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
#
#   REF_AREA_LABEL        INDICATOR  \
# 0    Afghanistan  FAO_EMSTOT_6518
# 1    Afghanistan  FAO_EMSTOT_6518
# 2    Afghanistan  FAO_EMSTOT_6518
# 3    Afghanistan  FAO_EMSTOT_6518
# 4    Afghanistan  FAO_EMSTOT_6518
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 1  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 2  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 3  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 4  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
#
#   UNIT_MULT_LABEL UNIT_TYPE  UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0           Units     COUNT  Count (Integer)         602              CCYY
# 1           Units     COUNT  Count (Integer)         602              CCYY
# 2           Units     COUNT  Count (Integer)         602              CCYY
# 3           Units     COUNT  Count (Integer)         602              CCYY
# 4           Units     COUNT  Count (Integer)         602              CCYY
#
#   OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0          A     Normal value       PU         Public
# 1          A     Normal value       PU         Public
# 2          A     Normal value       PU         Public
# 3          A     Normal value       PU         Public
# 4          A     Normal value       PU         Public
#
# [5 rows x 37 columns]

# %% [markdown]
# ### **Check DataFrame Shape**
# This cell prints the number of rows and columns in the DataFrame `df`.

# %%
df.shape
# Out:
# (12639, 37)

# %% [markdown]
# ### **Display DataFrame Information**
# This cell provides a summary of the DataFrame, including column names, non-null counts, and data types, to identify potential issues like missing values or incorrect data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12639 entries, 0 to 12638
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               12639 non-null  object
#  1   STRUCTURE_ID            12639 non-null  object
#  2   ACTION                  12639 non-null  object
#  3   FREQ                    12639 non-null  object
#  4   FREQ_LABEL              12639 non-null  object
#  5   REF_AREA                12639 non-null  object
#  6   REF_AREA_LABEL          12639 non-null  object
#  7   INDICATOR               12639 non-null  object
#  8   INDICATOR_LABEL         12639 non-null  object
#  9   SEX                     12639 non-null  object
#  10  SEX_LABEL               12639 non-null  object
#  11  AGE                     12639 non-null  object
#  12  AGE_LABEL               12639 non-null  object
#  13  URBANISATION            12639 non-null  object
#  14  URBANISATION_LABEL      12639 non-null  object
#  15  UNIT_MEASURE            12639 non-null  object
#  16  UNIT_MEASURE_LABEL      12639 non-null  object
#  17  COMP_BREAKDOWN_1        12639 non-null  object
#  18  COMP_BREAKDOWN_1_LABEL  12639 non-null  object
#  19  COMP_BREAKDOWN_2        12639 non-null  object
#  20  COMP_BREAKDOWN_2_LABEL  12639 non-null  object
#  21  COMP_BREAKDOWN_3        12639 non-null  object
#  22  COMP_BREAKDOWN_3_LABEL  12639 non-null  object
#  23  TIME_PERIOD             12639 non-null  int64
#  24  OBS_VALUE               12639 non-null  float64
#  25  DATABASE_ID             12639 non-null  object
#  26  DATABASE_ID_LABEL       12639 non-null  object
#  27  UNIT_MULT               12639 non-null  int64
#  28  UNIT_MULT_LABEL         12639 non-null  object
#  29  UNIT_TYPE               12639 non-null  object
#  30  UNIT_TYPE_LABEL         12639 non-null  object
#  31  TIME_FORMAT             12639 non-null  int64
#  32  TIME_FORMAT_LABEL       12639 non-null  object
#  33  OBS_STATUS              12639 non-null  object
#  34  OBS_STATUS_LABEL        12639 non-null  object
#  35  OBS_CONF                12639 non-null  object
#  36  OBS_CONF_LABEL          12639 non-null  object
# dtypes: float64(1), int64(3), object(33)
# memory usage: 3.6+ MB

# %% [markdown]
# ### **Check for Missing Values**
# This cell calculates and displays the count of missing values for each column in the DataFrame `df`.

# %%
df.isna().sum()
# Out:
# STRUCTURE                 0
# STRUCTURE_ID              0
# ACTION                    0
# FREQ                      0
# FREQ_LABEL                0
# REF_AREA                  0
# REF_AREA_LABEL            0
# INDICATOR                 0
# INDICATOR_LABEL           0
# SEX                       0
# SEX_LABEL                 0
# AGE                       0
# AGE_LABEL                 0
# URBANISATION              0
# URBANISATION_LABEL        0
# UNIT_MEASURE              0
# UNIT_MEASURE_LABEL        0
# COMP_BREAKDOWN_1          0
# COMP_BREAKDOWN_1_LABEL    0
# COMP_BREAKDOWN_2          0
# COMP_BREAKDOWN_2_LABEL    0
# COMP_BREAKDOWN_3          0
# COMP_BREAKDOWN_3_LABEL    0
# TIME_PERIOD               0
# OBS_VALUE                 0
# DATABASE_ID               0
# DATABASE_ID_LABEL         0
# UNIT_MULT                 0
# UNIT_MULT_LABEL           0
# UNIT_TYPE                 0
# UNIT_TYPE_LABEL           0
# TIME_FORMAT               0
# TIME_FORMAT_LABEL         0
# OBS_STATUS                0
# OBS_STATUS_LABEL          0
# OBS_CONF                  0
# OBS_CONF_LABEL            0
# dtype: int64

# %% [markdown]
# ### **Check for Duplicate Rows**
# This cell counts and displays the number of duplicate rows in the DataFrame `df`.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Print Column Names**
# This cell prints all column names in the DataFrame `df`.

# %%
print(df.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD',
#        'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT',
#        'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT',
#        'TIME_FORMAT_LABEL', 'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF',
#        'OBS_CONF_LABEL'],
#       dtype='object')

# %% [markdown]
# ### **Descriptive Statistics of Numeric Features**
# This cell generates descriptive statistics (count, mean, std, min, 25%, 50%, 75%, max) for all numeric columns in the DataFrame `df`.

# %%
df.describe().T
# Out:
#                count           mean            std     min         25%  \
# TIME_PERIOD  12639.0    1993.040905      17.435001  1961.0  1978.00000
# OBS_VALUE    12639.0  109094.828405  832089.803107     0.0   391.55215
# UNIT_MULT    12639.0       0.000000       0.000000     0.0     0.00000
# TIME_FORMAT  12639.0     602.000000       0.000000   602.0   602.00000
#
#                    50%          75%           max
# TIME_PERIOD  1994.0000   2008.00000  2.021000e+03
# OBS_VALUE    9600.9698  32820.36635  1.655949e+07
# UNIT_MULT       0.0000      0.00000  0.000000e+00
# TIME_FORMAT   602.0000    602.00000  6.020000e+02

# %% [markdown]
# ### **Outlier Detection using IQR Method**
# This cell identifies outliers in numeric columns using the Interquartile Range (IQR) method and summarizes the findings.

# %%
import pandas as pd

outlier_summary = []

numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)][col].values
    outlier_count = len(outliers)

    if outlier_count > 0:
        outlier_summary.append({
            'feature': col,
            'Q1': Q1,
            'Q3': Q3,
            'lower_bound': lower,
            'upper_bound': upper,
            'outlier_count': outlier_count,
            'outlier_values': outliers
        })

outlier_df = pd.DataFrame(outlier_summary)
outlier_df
# Out:
#      feature         Q1           Q3  lower_bound  upper_bound  outlier_count  \
# 0  OBS_VALUE  391.55215  32820.36635 -48251.66915  81463.58765           1717
#
#                                       outlier_values
# 0  [82807.0851, 88561.2177, 90247.8583, 90926.471...

# %% [markdown]
# ### **Visualize Numeric Feature Distributions and Outliers**
# This cell generates box plots for all numeric features to visually inspect their distributions and identify outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

numeric_df = df.select_dtypes(include=['number'])

columns_to_plot = []
for col in numeric_df.columns:
    if col == 'COMMENT_OBS' and df[col].isnull().all():
        continue
    if df[col].nunique() > 1:
        columns_to_plot.append(col)


if not columns_to_plot:
    print("No suitable numeric columns found for boxplot visualization.")
else:
    num_features = len(columns_to_plot)
    num_cols = 3
    num_rows = math.ceil(num_features / num_cols)

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(num_cols * 5, num_rows * 4))
    axes = axes.flatten()

    for i, col in enumerate(columns_to_plot):
        sns.boxplot(y=df[col], ax=axes[i])
        axes[i].set_title(col)
        axes[i].set_ylabel('')

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.suptitle('Distribution and Outliers of Numeric Features (Before Outlier Capping)', y=1.02, fontsize=16)
    plt.show()

# %% [markdown]
# ### **Outlier Capping**
# This cell applies outlier capping to the numeric columns in the DataFrame `df_capped` using the IQR method, limiting values to within 1.5 times the IQR from the quartiles.

# %%
import numpy as np

df_capped = df.copy()

numeric_cols_for_capping = df_capped.select_dtypes(include=np.number).columns

print("Applying outlier capping to the following numeric columns:")
for col in numeric_cols_for_capping:
    if col == 'COMMENT_OBS':
        continue

    Q1 = df_capped[col].quantile(0.25)
    Q3 = df_capped[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_capped[col] = df_capped[col].clip(lower=lower_bound, upper=upper_bound)
    print(f"- {col}: Outliers capped between {lower_bound:.2f} and {upper_bound:.2f}")

print("\nOutlier capping process completed for all numeric columns.")
print("\nHead of DataFrame after outlier capping (df_capped):")
display(df_capped.head())
# Out:
# Applying outlier capping to the following numeric columns:
# - TIME_PERIOD: Outliers capped between 1933.00 and 2053.00
# - OBS_VALUE: Outliers capped between -48251.67 and 81463.59
# - UNIT_MULT: Outliers capped between 0.00 and 0.00
# - TIME_FORMAT: Outliers capped between 602.00 and 602.00
#
# Outlier capping process completed for all numeric columns.
#
# Head of DataFrame after outlier capping (df_capped):
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
#
#   REF_AREA_LABEL        INDICATOR  \
# 0    Afghanistan  FAO_EMSTOT_6518
# 1    Afghanistan  FAO_EMSTOT_6518
# 2    Afghanistan  FAO_EMSTOT_6518
# 3    Afghanistan  FAO_EMSTOT_6518
# 4    Afghanistan  FAO_EMSTOT_6518
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 1  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 2  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 3  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 4  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
#
#   UNIT_MULT_LABEL UNIT_TYPE  UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0           Units     COUNT  Count (Integer)         602              CCYY
# 1           Units     COUNT  Count (Integer)         602              CCYY
# 2           Units     COUNT  Count (Integer)         602              CCYY
# 3           Units     COUNT  Count (Integer)         602              CCYY
# 4           Units     COUNT  Count (Integer)         602              CCYY
#
#   OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0          A     Normal value       PU         Public
# 1          A     Normal value       PU         Public
# 2          A     Normal value       PU         Public
# 3          A     Normal value       PU         Public
# 4          A     Normal value       PU         Public
#
# [5 rows x 37 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

numeric_df_capped = df_capped.select_dtypes(include=['number'])

columns_to_plot_capped = []
for col in numeric_df_capped.columns:
    if numeric_df_capped[col].nunique() > 1:
        columns_to_plot_capped.append(col)

if not columns_to_plot_capped:
    print("No suitable numeric columns found for boxplot visualization after capping.")
else:
    num_features = len(columns_to_plot_capped)
    num_cols = 3
    num_rows = math.ceil(num_features / num_cols)

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(num_cols * 5, num_rows * 4))
    axes = axes.flatten()

    for i, col in enumerate(columns_to_plot_capped):
        sns.boxplot(y=df_capped[col], ax=axes[i])
        axes[i].set_title(col)
        axes[i].set_ylabel('')

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.suptitle('Distribution and Outliers of Numeric Features (After Outlier Capping)', y=1.02, fontsize=16)
    plt.show()

# %% [markdown]
# ### **Verify Outlier Capping for TIME_PERIOD**
# This cell displays descriptive statistics for the 'TIME_PERIOD' column after outlier capping to verify the changes.

# %%
display(df_capped['TIME_PERIOD'].describe().T)
# Out:
# count    12639.000000
# mean      1993.040905
# std         17.435001
# min       1961.000000
# 25%       1978.000000
# 50%       1994.000000
# 75%       2008.000000
# max       2021.000000
# Name: TIME_PERIOD, dtype: float64

# %% [markdown]
# ### **Verify Outlier Capping for OBS_VALUE**
# This cell displays descriptive statistics for the 'OBS_VALUE' column after outlier capping to verify the changes.

# %%
display(df_capped['OBS_VALUE'].describe().T)
# Out:
# count    12639.000000
# mean     22585.845014
# std      28639.722624
# min          0.000000
# 25%        391.552150
# 50%       9600.969800
# 75%      32820.366350
# max      81463.587650
# Name: OBS_VALUE, dtype: float64

# %% [markdown]
# ### **Drop Unnecessary Columns**
# This cell drops a predefined list of columns that are not considered relevant for further analysis from the DataFrame `df_cleaned`.

# %%
columns_to_drop = [
    'STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'REF_AREA',
    'INDICATOR', 'SEX', 'AGE', 'URBANISATION', 'UNIT_MEASURE',
    'COMP_BREAKDOWN_1', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_3',
    'DATABASE_ID', 'UNIT_MULT', 'UNIT_TYPE', 'TIME_FORMAT',
    'OBS_STATUS', 'OBS_CONF',
    'FREQ_LABEL',
    'Breakdown_1', 'Breakdown_2', 'Breakdown_3'
]

df_cleaned = df_renamed.drop(columns=columns_to_drop, errors='ignore')

print("DataFrame columns after dropping unnecessary columns:")
print(df_cleaned.columns.tolist())

print("\nFirst 5 rows of the cleaned DataFrame:")
display(df_cleaned.head())
# Out:
# DataFrame columns after dropping unnecessary columns:
# ['Country', 'Indicator', 'Sex', 'Age', 'Urbanisation', 'Unit_Measure', 'Component_1', 'Component_2', 'Component_3', 'TIME_PERIOD', 'OBS_VALUE', 'Database', 'Unit_Multiplier', 'Unit_Type', 'Time_Format_Label_Desc', 'Observation_Status', 'Observation_Confidence']
#
# First 5 rows of the cleaned DataFrame:
#        Country                                          Indicator    Sex  \
# 0  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 1  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 2  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 3  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 4  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
#
#                                      Age Urbanisation Unit_Measure  \
# 0  All age ranges or no breakdown by age        Total   Kilotonnes
# 1  All age ranges or no breakdown by age        Total   Kilotonnes
# 2  All age ranges or no breakdown by age        Total   Kilotonnes
# 3  All age ranges or no breakdown by age        Total   Kilotonnes
# 4  All age ranges or no breakdown by age        Total   Kilotonnes
#
#       Component_1     Component_2     Component_3  TIME_PERIOD   OBS_VALUE  \
# 0  Not Applicable  Not Applicable  Not Applicable         1961  10783.7374
# 1  Not Applicable  Not Applicable  Not Applicable         1962  10899.2453
# 2  Not Applicable  Not Applicable  Not Applicable         1963  11258.7671
# 3  Not Applicable  Not Applicable  Not Applicable         1964  11454.0975
# 4  Not Applicable  Not Applicable  Not Applicable         1965  11717.5817
#
#            Database Unit_Multiplier        Unit_Type Time_Format_Label_Desc  \
# 0  Emissions Totals           Units  Count (Integer)                   CCYY
# 1  Emissions Totals           Units  Count (Integer)                   CCYY
# 2  Emissions Totals           Units  Count (Integer)                   CCYY
# 3  Emissions Totals           Units  Count (Integer)                   CCYY
# 4  Emissions Totals           Units  Count (Integer)                   CCYY
#
#   Observation_Status Observation_Confidence
# 0       Normal value                 Public
# 1       Normal value                 Public
# 2       Normal value                 Public
# 3       Normal value                 Public
# 4       Normal value                 Public

# %% [markdown]
# ### **Rename Columns for Clarity**
# This cell renames several columns in `df_cleaned` to more descriptive and user-friendly names, creating `df_final`.

# %%
final_rename_mapping = {
    'Unit_Multiplier': 'Unit_Mult',
    'Observation_Status': 'Obs_Status',
    'Observation_Confidence': 'Obs_Conf'
}

df_final = df_cleaned.rename(columns=final_rename_mapping)

print("Final DataFrame columns after further renaming:")
print(df_final.columns.tolist())

print("\nFirst 5 rows of the final cleaned and renamed DataFrame:")
display(df_final.head())
# Out:
# Final DataFrame columns after further renaming:
# ['Country', 'Indicator', 'Sex', 'Age', 'Urbanisation', 'Unit_Measure', 'Component_1', 'Component_2', 'Component_3', 'TIME_PERIOD', 'OBS_VALUE', 'Database', 'Unit_Mult', 'Unit_Type', 'Time_Format_Label_Desc', 'Obs_Status', 'Obs_Conf']
#
# First 5 rows of the final cleaned and renamed DataFrame:
#        Country                                          Indicator    Sex  \
# 0  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 1  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 2  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 3  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 4  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
#
#                                      Age Urbanisation Unit_Measure  \
# 0  All age ranges or no breakdown by age        Total   Kilotonnes
# 1  All age ranges or no breakdown by age        Total   Kilotonnes
# 2  All age ranges or no breakdown by age        Total   Kilotonnes
# 3  All age ranges or no breakdown by age        Total   Kilotonnes
# 4  All age ranges or no breakdown by age        Total   Kilotonnes
#
#       Component_1     Component_2     Component_3  TIME_PERIOD   OBS_VALUE  \
# 0  Not Applicable  Not Applicable  Not Applicable         1961  10783.7374
# 1  Not Applicable  Not Applicable  Not Applicable         1962  10899.2453
# 2  Not Applicable  Not Applicable  Not Applicable         1963  11258.7671
# 3  Not Applicable  Not Applicable  Not Applicable         1964  11454.0975
# 4  Not Applicable  Not Applicable  Not Applicable         1965  11717.5817
#
#            Database Unit_Mult        Unit_Type Time_Format_Label_Desc  \
# 0  Emissions Totals     Units  Count (Integer)                   CCYY
# 1  Emissions Totals     Units  Count (Integer)                   CCYY
# 2  Emissions Totals     Units  Count (Integer)                   CCYY
# 3  Emissions Totals     Units  Count (Integer)                   CCYY
# 4  Emissions Totals     Units  Count (Integer)                   CCYY
#
#      Obs_Status Obs_Conf
# 0  Normal value   Public
# 1  Normal value   Public
# 2  Normal value   Public
# 3  Normal value   Public
# 4  Normal value   Public

# %% [markdown]
# ### **Min-Max Normalization**
# This cell applies Min-Max normalization to selected numeric columns in a copy of the DataFrame (`df_normalized`), scaling values to a range between 0 and 1.

# %%
from sklearn.preprocessing import MinMaxScaler

df_normalized = df_capped.copy()

numeric_cols_to_normalize = [
    col for col in df_normalized.select_dtypes(include=['number']).columns
    if df_normalized[col].nunique() > 1 and col not in ['UNIT_MULT', 'TIME_FORMAT']
]

scaler = MinMaxScaler()

df_normalized[numeric_cols_to_normalize] = scaler.fit_transform(df_normalized[numeric_cols_to_normalize])

print("DataFrame after Min-Max normalization:")
display(df_normalized.head())
# Out:
# DataFrame after Min-Max normalization:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
#
#   REF_AREA_LABEL        INDICATOR  \
# 0    Afghanistan  FAO_EMSTOT_6518
# 1    Afghanistan  FAO_EMSTOT_6518
# 2    Afghanistan  FAO_EMSTOT_6518
# 3    Afghanistan  FAO_EMSTOT_6518
# 4    Afghanistan  FAO_EMSTOT_6518
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT  \
# 0  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 1  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 2  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 3  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
# 4  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  _T  ...         0
#
#   UNIT_MULT_LABEL UNIT_TYPE  UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0           Units     COUNT  Count (Integer)         602              CCYY
# 1           Units     COUNT  Count (Integer)         602              CCYY
# 2           Units     COUNT  Count (Integer)         602              CCYY
# 3           Units     COUNT  Count (Integer)         602              CCYY
# 4           Units     COUNT  Count (Integer)         602              CCYY
#
#   OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0          A     Normal value       PU         Public
# 1          A     Normal value       PU         Public
# 2          A     Normal value       PU         Public
# 3          A     Normal value       PU         Public
# 4          A     Normal value       PU         Public
#
# [5 rows x 37 columns]

# %% [markdown]
# ### **Standardization (Z-score Scaling)**
# This cell applies standardization (Z-score scaling) to selected numeric columns in a copy of the DataFrame (`df_standardized`), transforming data to have a mean of 0 and a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler

df_standardized = df_final.copy()

numeric_cols_to_standardize = [
    col for col in df_standardized.select_dtypes(include=['number']).columns
    if df_standardized[col].nunique() > 1 and col not in ['Unit_Mult', 'Time_Format']
]

scaler = StandardScaler()

df_standardized[numeric_cols_to_standardize] = scaler.fit_transform(df_standardized[numeric_cols_to_standardize])

print("DataFrame after Standardization:")
display(df_standardized.head())
# Out:
# DataFrame after Standardization:
#        Country                                          Indicator    Sex  \
# 0  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 1  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 2  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 3  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
# 4  Afghanistan  Greenhouse gas (GHG) emissions (CO2eq) (AR5) g...  Total
#
#                                      Age Urbanisation Unit_Measure  \
# 0  All age ranges or no breakdown by age        Total   Kilotonnes
# 1  All age ranges or no breakdown by age        Total   Kilotonnes
# 2  All age ranges or no breakdown by age        Total   Kilotonnes
# 3  All age ranges or no breakdown by age        Total   Kilotonnes
# 4  All age ranges or no breakdown by age        Total   Kilotonnes
#
#       Component_1     Component_2     Component_3  TIME_PERIOD  OBS_VALUE  \
# 0  Not Applicable  Not Applicable  Not Applicable    -1.837807  -0.412105
# 1  Not Applicable  Not Applicable  Not Applicable    -1.780449  -0.408072
# 2  Not Applicable  Not Applicable  Not Applicable    -1.723091  -0.395518
# 3  Not Applicable  Not Applicable  Not Applicable    -1.665733  -0.388697
# 4  Not Applicable  Not Applicable  Not Applicable    -1.608375  -0.379497
#
#            Database Unit_Mult        Unit_Type Time_Format_Label_Desc  \
# 0  Emissions Totals     Units  Count (Integer)                   CCYY
# 1  Emissions Totals     Units  Count (Integer)                   CCYY
# 2  Emissions Totals     Units  Count (Integer)                   CCYY
# 3  Emissions Totals     Units  Count (Integer)                   CCYY
# 4  Emissions Totals     Units  Count (Integer)                   CCYY
#
#      Obs_Status Obs_Conf
# 0  Normal value   Public
# 1  Normal value   Public
# 2  Normal value   Public
# 3  Normal value   Public
# 4  Normal value   Public
